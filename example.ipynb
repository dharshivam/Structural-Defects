# %% [markdown]
# ### Loading Images in Python

# %%
#pip install pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# from PIL import Image

# %%
from PIL import Image

# %%
image_link = r"D:\GEN AI FINAL WEEK\STRUCTURAL_DEFECTS\honeycomb_structure.jpeg"

# %%
defect_image = Image.open(image_link)

# %%
defect_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x375>

# %% [markdown]
# ### Lets see if we can identify the defected area

# %%
import google.generativeai as genai
from PIL import Image
import os

# %%
genai.configure(api_key=os.getenv("GOOGLE_API_KEY"))
model = genai.GenerativeModel('gemini-2.5-flash-lite')
prompt = 'Tell me a good joke on engineering in short different way'
response = model.generate_content(prompt,generation_config={'top_k':1})
print(response.text)
# Out:
# Why did the engineer break up with the circle?
#
# Because it had no point.

# %% [markdown]
# Methods to Control Randomness in the output:
#
# Temperature (Controls the randomness and creativity)
# * 0-> deterministic , focused and factual
# * 1-> balanced creativity
# * greater than 1 -> More diverse and less Coherent

# %%
prompt = ''' In the uploaded image . Identify the defected area and mark in the image.Return 
the image only.

'''

# %%
response = model.generate_content(
    prompt)

# %%
import datetime as dt
print(dt.datetime.now().date())
# Out:
# 2025-09-17

# %%
print(dt.datetime.now().time())

# %% [markdown]
# ## Defining file formats in streamlit(mime)
